# %% [markdown]
# # Simple linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from pylab import rcParams
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10,8

# %%
rooms = np.random.randn(100,1)+3
rooms[0:10]
# Out:
# array([[3.50535857],
#        [2.5258662 ],
#        [2.40586442],
#        [4.47273347],
#        [3.91105569],
#        [3.1427517 ],
#        [1.42889813],
#        [2.37739557],
#        [4.11214909],
#        [1.47696466]])

# %%
price = 265+6*rooms + abs(np.random.randn(100,1))
price[0:10]
# Out:
# array([[286.04914154],
#        [280.39540266],
#        [280.14338135],
#        [293.34406437],
#        [288.88567985],
#        [284.27543157],
#        [274.89606331],
#        [279.64516437],
#        [290.2587463 ],
#        [274.39067769]])

# %%
plt.plot(rooms, price, 'r^')
plt.xlabel('number of rooms, 2024 average')
plt.ylabel('2024 average home price $1000s USD')
plt.show()

# %%
X =rooms
y=price

LinReg = LinearRegression()
LinReg.fit(X,y)
print(LinReg.intercept_,LinReg.coef_)
# Out:
# [265.86684992] [[5.95421849]]

# %% [markdown]
# *Simple Algebra*
# - y = mx + b
# - b = intercept = 265.86
#
# *Estimated Coefficients*
# - LinReg.coef_ = [5.95] Estimated coefficients for the terms in the linear regression problem.

# %%
print(LinReg.score(X,y))
# Out:
# 0.9903128608488785
